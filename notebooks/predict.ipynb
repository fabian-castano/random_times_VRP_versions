# %% [markdown]
# # import the required libraries

# %%
import pandas as pd
import numpy as np
import sympy as sp

# %%
import sys
sys.path.append('../')
from src.osrm_client import OSRMClient
from src.utils import FindMiddlePointsSymbol

# %% [markdown]
# # Solving linear functions
#
# Defines a function to solve the linear system used to determine the lines joining the middle point of each time block that will be used to represent the travel time between a pair of locations

# %%
# the number of middle points (hours) to be computed
T = 24

# mus are the average travel times from the origin to the middle points during the hours being computed
mus=FindMiddlePointsSymbol(T)

# us are the middle points heights (travel time starting from the origin)
u=sp.symbols('u_0:24')

# %%
## an example of the middle points
for t in range(24):
    print(f"u_{t} = {mus[t].subs([(u[i],10*i) for i in range(24)])}")
# Out:
# u_0 = -42.1286011665935
# u_1 = -25.6340082939300
# u_2 = 39.1570330435841
# u_3 = 29.4587117318881
# u_4 = 40.5004711354100
# u_5 = 49.9315574523946
# u_6 = 59.9956564840330
# u_7 = 69.9983577301374
# u_8 = 80.0003140446165
# u_9 = 89.9999640047183
# u_10 = 100.000008073271
# u_11 = 110.000000105327
# u_12 = 119.999999970831
# u_13 = 130.000000769536
# u_14 = 139.999993782199
# u_15 = 150.000036345419
# u_16 = 159.999788147082
# u_17 = 170.001234774081
# u_18 = 179.992803208981
# u_19 = 190.041945971970
# u_20 = 199.755520959255
# u_21 = 211.424928272513
# u_22 = 211.694909405666
# u_23 = 278.405615293488

# %% [markdown]
# # Computing coefficient matrix to generalize computations

# %%
Matriz=np.zeros(shape=(24,24))


for i in range(24):
    for j in range(24):
        a = sp.Poly(mus[i], u[j])
        try:
            Matriz[i,j]=a.all_coeffs()[0]
        except:
            Matriz[i,j]=0

# %% [markdown]
# # deploying the prediction engine tha after will feed the piecewise linear function between each pair of persons

# %%
# load pickled model from file in data/train/models
model = pd.read_pickle('/Users/fabiancastano/Documents/HHCRSP/data/train/models/random_forest_model.pkl')
model
# Out:
# Pipeline(steps=[('scaler', MinMaxScaler()), ('model', RandomForestRegressor())])

# %% [markdown]
# # an usage example of the model

# %%
origin = (4.565939989750968,-74.0806071365743)
destination = 4.653234735184246,-74.1509113415633
# inverted origin and destination
origin = (origin[1], origin[0])
destination = (destination[1], destination[0])
osrm = OSRMClient("127.0.0.1:5001")
distance=osrm.get_distance(origin, destination)
distance
# Out:
# 16.9634

# %%
# person 1 -74.1315010003499,4.566350000382421
# person 2 -74.18814699967187,4.6310979997131225
lat1, lon1 = 4.737315, -74.029834
lat2, lon2 =  4.612753, -74.077734



# create OSRM client and request distance between two points
osrm = OSRMClient("127.0.0.1:5001")
distance=osrm.get_distance([lon1,lat1 ], [lon2, lat2])
print(f"Distance: {distance} km")
X = np.array([[lon1, lat1, lon2, lat2,  distance, t] for t in range(24)])

predictions = model.predict(X)
predictions
# Out:
# Distance: 18.3225 km
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# array([ 669.0769,  764.7889, 1044.6835,  983.1809, 1027.5093, 1095.382 ,
#        1699.4631, 1530.8451, 1591.1518, 1522.4836, 1876.6246, 1912.6213,
#        1640.5016, 1704.6669, 1687.5691, 1549.9615, 1299.4089, 1272.0585,
#        1247.3234, 1226.0954, 1783.1954, 1155.2006, 1023.5961,  606.434 ])

# %%
middle_hours=[(0.5+i) for i in range(24)]

heights = Matriz.dot(predictions)

# middle_hours has a new value in position zero which is the first hour to consider
middle_hours = [-0.5] + middle_hours
# heights has a new value in posiition zero which is equal to the value in the last postion
new_heights = []
new_heights.append(heights[-1])
new_heights.extend(heights)

# range of small values with numpy
new_heights
f = np.vectorize(lambda x: np.interp(x, middle_hours, new_heights))

# %%
def get_travel_time_function(model, origin, destination):

    distance=osrm.get_distance(origin, destination)

    X = np.array([[origin[0], origin[1], destination[0], destination[1],  distance, t] for t in range(24)])
    predictions = model.predict(X)
    print(predictions)
    # create OSRM client and request distance between two points
    middle_hours=[-0.5] + [(0.5+i) for i in range(24)]
    heights = Matriz.dot(predictions)
    new_heights = []
    new_heights.append(heights[-1])
    new_heights.extend(heights)
    
    print([[middle_hours[i], new_heights[i]] for i in range(25)])

    return np.vectorize(lambda x: np.interp(x, middle_hours, new_heights))

f = get_travel_time_function(model, [lon2, lat2], [lon1, lat1] )

import matplotlib.pyplot as plt
x = np.arange(0, 24, 0.01)
plt.plot(x, f(x), label='Travel time', color='red', linewidth=2)
plt.show()
# Out:
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# [ 741.4013  657.5726  594.888   600.6145  630.1703 1023.4334  904.5
#   873.8291  648.3747  641.043   746.1867  777.9486 1087.837  1124.3764
#  1097.4773 1218.2378 1129.8871 1333.9793 1395.7527 1212.3038 1136.398
#  1058.6334  961.1562  778.6997]
# [[-0.5, np.float64(743.4522184893503)], [0.5, np.float64(787.5467671329183)], [1.5, np.float64(462.47757871312865)], [2.5, np.float64(649.8557261378267)], [3.5, np.float64(607.830616181068)], [4.5, np.float64(551.8971343018713)], [5.5, np.float64(1128.5395077904245)], [6.5, np.float64(864.5612845803553)], [7.5, np.float64(919.8360640601277)], [8.5, np.float64(607.0180849890066)], [9.5, np.float64(625.0535972004586)], [10.5, np.float64(771.0046337586228)], [11.5, np.float64(718.4122490648278)], [12.5, np.float64(1142.11070658594)], [13.5, np.float64(1131.6195146181526)], [14.5, np.float64(1063.1833986589286)], [15.5, np.float64(1269.098492647528)], [16.5, np.float64(1068.1280454841342)], [17.5, np.float64(1361.2300344589905)], [18.5, np.float64(1436.326147764723)], [19.5, np.float64(1186.8346789525133)], [20.5, np.float64(1141.0961785204638)], [21.5, np.float64(1057.7722499247598)], [22.5, np.float64(981.3375219309811)], [23.5, np.float64(743.4522184893503)]]

# %% [markdown]
# # read an instance

# %%
df_positions = pd.read_csv('/Users/fabiancastano/Documents/HHCRSP/new_Instances/HHC_25_4.csv')
df_positions.columns=['id','index','lon','lat','service_time','service_number','opt1','opt2','opt3']
df_positions.drop(columns=['index'],inplace=True)

df_positions['position'] = list(zip(df_positions['lon'],df_positions['lat']))

positions =  df_positions.set_index('id').to_dict()['position']

tw = {}

for i in range(26):
    s= np.random.randint(6,18)
    e = s + np.random.randint(1,3)/2
    if i == 0:
        tw[i] = (0,24)
        continue
    tw[i] = (s,e)

# %% [markdown]
# # builds a travel time matrix where each position corresponds to the piecewise linear function

# %%
travel_time_matrix = {}

for i in range(len(positions)):
    for j in range(len(positions)):
        if i!=j:
            origin = positions[i]
            destination = positions[j]
            travel_time_matrix[i,j] = get_travel_time_function(model, origin, destination)
# Out:
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# ...
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/fabiancastano/Documents/HHCRSP/venv/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(

# %%
def evaluate(ruta,travel_time_matrix,start_time=6,log_route_info=False):
    current_time = start_time
    travel_time = 0
    late_time = 0
    visited = [ruta[0]]
    for i in range(len(ruta)-1):
        tt = np.round(travel_time_matrix[ruta[i],ruta[i+1]](current_time)/3600,2)
        
        if current_time+tt<18:
            visited.append(ruta[i+1])
            travel_time+=tt
            if current_time+tt>tw[ruta[i+1]][1]:
                current_time+=tt
                late_time+=current_time-tw[ruta[i+1]][1]
            if current_time<tw[ruta[i+1]][0]:
                current_time = tw[ruta[i+1]][0]            
        else:
            break

    return travel_time, late_time, len(ruta)-len(visited)

ruta = [0] + np.random.permutation(range(1,12)).tolist() + [0]
evaluate(ruta,travel_time_matrix,start_time=6)
# Out:
# (np.float64(2.89), np.float64(8.959999999999999), 6)

# %%
def one_at_a_time_swap(ruta,
                       travel_time_matrix,
                       tw,
                        start_time=6):

    best_ruta = ruta
    best = np.inf
    for i in range(1,len(ruta)-2):
        for j in range(i+1,len(ruta)-1):
            new_ruta = ruta.copy()
            new_ruta[i], new_ruta[j] = new_ruta[j], new_ruta[i]
            fobj_tt, fobj_late, fobj_nv = evaluate(new_ruta,travel_time_matrix,start_time)
            total_cost= fobj_tt + 10*fobj_late + 100*fobj_nv
            if total_cost<best:
                best = total_cost
                best_ruta = new_ruta

    return best,best_ruta

ruta = [0] + np.random.permutation(range(1,12)).tolist() + [0]
one_at_a_time_swap(ruta,travel_time_matrix,tw,start_time=6)
# Out:
# (np.float64(681.3499999999999), [0, 7, 11, 5, 3, 4, 6, 9, 10, 1, 8, 2, 0])

# %%
def two_opt(ruta,
            travel_time_matrix,
            tw,
            start_time=6):

    best_ruta = ruta
    best = np.inf
    for i in range(1,len(ruta)-2):
        for j in range(i+1,len(ruta)-1):
            
            new_ruta = ruta[:i] + ruta[i:j][::-1] + ruta[j+1:]
            fobj_tt, fobj_late, fobj_nv = evaluate(new_ruta,travel_time_matrix,start_time)
            total_cost= fobj_tt + 10*fobj_late + 100*fobj_nv
            if total_cost<best:
                best = total_cost
                best_ruta = new_ruta
    return best_ruta, best

ruta = [0] + np.random.permutation(range(1,12)).tolist() + [0]
two_opt(ruta,travel_time_matrix,tw,start_time=6)
# Out:
# ([0, 9, 8, 6, 7, 10, 1, 2, 4, 3, 11, 0], np.float64(398.27))

# %%
class TabuSearch:

    def __init__(self, travel_time_matrix, tw, start_time=6):
        self.travel_time_matrix = travel_time_matrix
        self.tw = tw
        self.start_time = start_time

    def initial_solution(self):
        return [0] + np.random.permutation(range(1,12)).tolist() + [0]


    def one_at_a_time_swap(self, ruta):
        best_ruta = ruta
        best = np.inf
        for i in range(1,len(ruta)-2):
            for j in range(i+1,len(ruta)-1):
                new_ruta = ruta.copy()
                new_ruta[i], new_ruta[j] = new_ruta[j], new_ruta[i]
                fobj_tt, fobj_late, fobj_nv = evaluate(new_ruta,self.travel_time_matrix,self.start_time)
                total_cost= fobj_tt + 10*fobj_late + 100*fobj_nv
                if total_cost<best:
                    best = total_cost
                    best_ruta = new_ruta

        return best,best_ruta
    
    def two_opt(self, ruta):
        best_ruta = ruta
        best = np.inf
        for i in range(1,len(ruta)-2):
            for j in range(i+1,len(ruta)-1):
                new_ruta = ruta[:i] + ruta[i:j][::-1] + ruta[j+1:]
                fobj_tt, fobj_late, fobj_nv = evaluate(new_ruta,self.travel_time_matrix,self.start_time)
                total_cost= fobj_tt + 10*fobj_late + 100*fobj_nv
                if total_cost<best:
                    best = total_cost
                    best_ruta = new_ruta
        return best_ruta, best
    
    def run(self, ruta, max_iter=1000):
        best= np.inf
        for i in range(max_iter):
            objf,route = self.one_at_a_time_swap(ruta)
            if objf<best:
                best = objf
                best_ruta = route
            objf,route = self.two_opt(ruta)
            if objf<best:
                best = objf
                best_ruta = route
        return best_ruta, best
    
ts = TabuSearch(travel_time_matrix, tw, start_time=6)







best= np.inf
for i in range(1000):
    ruta = [0] + np.random.permutation(range(1,10)).tolist() + [0]
    start_time = 6
    fobj_tt, fobj_late, fobj_nv = evaluate(ruta,travel_time_matrix,start_time=start_time)
    best = fobj_tt + 10*fobj_late + 100*fobj_nv

    objf,route = one_at_a_time_swap(ruta,travel_time_matrix,tw,start_time=start_time)
    if objf<best:
        best = objf
        best_ruta = route
        print(f"new best with swap: {best}")
    objf,route == two_opt(ruta,travel_time_matrix,tw,start_time=start_time)
    if objf<best:
        best = objf
        best_ruta = route
        print(f"new best with 2 OPT: {best}")
# Out:
# new best with swap: 337.5
# new best with swap: 107.83000000000001
# new best with swap: 107.31999999999998
# new best with swap: 358.89000000000004
# new best with swap: 137.76000000000005
# new best with swap: 315.96999999999997
# new best with swap: 218.92000000000004
# new best with swap: 348.96000000000004
# new best with swap: 229.56
# new best with swap: 369.85
# new best with swap: 324.68999999999994
# new best with swap: 344.02
# new best with swap: 247.35999999999999
# new best with swap: 418.98
# new best with swap: 328.70000000000005
# new best with swap: 380.82
# new best with swap: 409.90999999999997
# new best with swap: 263.46
# new best with swap: 299.04
# new best with swap: 177.55
# new best with swap: 564.92
# new best with swap: 542.3199999999999
# new best with swap: 345.65
# new best with swap: 255.81
# new best with swap: 591.89
# new best with swap: 680.93
# new best with swap: 443.34000000000003
# new best with swap: 204.61000000000004
# new best with swap: 507.04
# new best with swap: 335.32
# new best with swap: 402.90000000000003
# new best with swap: 206.66000000000008
# new best with swap: 450.65
# new best with swap: 329.76
# new best with swap: 354.95000000000005
# new best with swap: 537.13
# new best with swap: 235.08
# new best with swap: 420.19
# new best with swap: 180.5
# new best with swap: 263.7700000000001
# new best with swap: 276.66
# new best with swap: 465.69
# new best with swap: 511.47
# new best with swap: 200.55
# new best with swap: 494.11
# new best with swap: 222.57000000000008
# new best with swap: 87.43000000000002
# new best with swap: 263.54
# new best with swap: 379.70000000000005
# new best with swap: 270.45
# new best with swap: 171.50000000000003
# new best with swap: 131.47
# new best with swap: 283.84999999999997
# new best with swap: 566.26
# new best with swap: 202.81
# new best with swap: 546.29
# new best with swap: 261.4200000000001
# new best with swap: 441.21
# new best with swap: 373.35
# new best with swap: 277.83000000000004
# new best with swap: 208.89000000000001
# new best with swap: 190.61000000000007
# new best with swap: 664.39
# new best with swap: 177.07
# new best with swap: 174.75
# new best with swap: 381.80000000000007
# new best with swap: 240.88
# new best with swap: 432.09000000000003
# new best with swap: 141.14
# new best with swap: 207.62999999999997
# new best with swap: 234.70000000000002
# new best with swap: 140.36
# new best with swap: 641.99
# new best with swap: 364.62
# new best with swap: 226.09000000000003
# new best with swap: 182.48000000000002
# new best with swap: 230.49999999999997
# new best with swap: 314.89
# new best with swap: 266.97
# new best with swap: 377.57
# new best with swap: 368.4000000000001
# new best with swap: 445.93000000000006
# new best with swap: 234.03999999999996
# new best with swap: 173.74000000000004
# new best with swap: 177.48000000000002
# new best with swap: 264.59999999999997
# new best with swap: 198.61
# new best with swap: 269.63999999999993
# new best with swap: 319.62
# new best with swap: 284.59
# new best with swap: 185.51999999999998
# new best with swap: 185.28
# new best with swap: 222.37000000000006
# new best with swap: 212.27
# new best with swap: 586.42
# new best with swap: 367.04999999999995
# new best with swap: 175.89000000000001
# new best with swap: 382.35
# new best with swap: 222.01000000000008
# new best with swap: 441.14
# new best with swap: 336.56
# new best with swap: 285.03999999999996
# new best with swap: 270.42
# new best with swap: 243.13
# new best with swap: 546.0
# new best with swap: 228.16
# new best with swap: 250.70999999999998
# new best with swap: 380.46999999999997
# new best with swap: 295.84000000000003
# new best with swap: 248.31
# new best with swap: 629.92
# new best with swap: 460.15
# new best with swap: 327.61
# new best with swap: 243.86
# new best with swap: 309.49
# new best with swap: 296.88000000000005
# new best with swap: 259.32000000000005
# new best with swap: 546.47
# new best with swap: 214.28000000000003
# new best with swap: 291.68000000000006
# new best with swap: 323.4
# new best with swap: 210.15000000000003
# new best with swap: 369.83000000000004
# new best with swap: 532.1600000000001
# new best with swap: 286.65999999999997
# new best with swap: 312.21
# new best with swap: 496.49
# new best with swap: 396.54
# new best with swap: 319.52
# new best with swap: 441.54999999999995
# new best with swap: 255.35000000000002
# new best with swap: 202.17000000000002
# new best with swap: 229.56
# new best with swap: 228.57999999999998
# new best with swap: 584.39
# new best with swap: 279.32000000000005
# new best with swap: 179.70000000000002
# new best with swap: 430.86
# new best with swap: 401.1
# new best with swap: 621.83
# new best with swap: 147.84999999999997
# new best with swap: 206.66000000000008
# new best with swap: 53.27000000000003
# new best with swap: 383.03000000000003
# new best with swap: 316.83
# new best with swap: 66.07999999999998
# new best with swap: 270.64
# new best with swap: 212.25999999999996
# new best with swap: 404.5100000000001
# new best with swap: 265.18
# new best with swap: 532.13
# new best with swap: 244.92000000000004
# new best with swap: 215.04000000000002
# new best with swap: 187.45999999999998
# new best with swap: 680.93
# new best with swap: 368.89000000000004
# new best with swap: 123.30999999999997
# new best with swap: 556.15
# new best with swap: 271.81999999999994
# new best with swap: 386.68000000000006
# new best with swap: 698.05
# new best with swap: 185.7299999999999
# new best with swap: 291.19999999999993
# new best with swap: 238.36
# new best with swap: 174.05
# new best with swap: 408.01
# new best with swap: 380.88
# new best with swap: 280.80000000000007
# new best with swap: 106.61000000000001
# new best with swap: 157.10000000000002
# new best with swap: 265.9
# new best with swap: 288.4
# new best with swap: 267.45
# new best with swap: 250.75
# new best with swap: 274.3
# new best with swap: 313.5
# new best with swap: 191.80000000000004
# new best with swap: 304.87
# new best with swap: 533.0
# new best with swap: 152.42000000000002
# new best with swap: 351.32000000000005
# new best with swap: 352.68
# new best with swap: 365.54999999999995
# new best with swap: 311.14
# new best with swap: 400.21000000000004
# new best with swap: 151.81
# new best with swap: 136.33
# new best with swap: 394.16999999999996
# new best with swap: 271.0200000000001
# new best with swap: 546.35
# new best with swap: 420.23
# new best with swap: 444.55
# new best with swap: 443.90999999999997
# new best with swap: 566.56
# new best with swap: 316.08
# new best with swap: 501.86
# new best with swap: 437.59000000000003
# new best with swap: 346.25
# new best with swap: 301.6600000000001
# new best with swap: 178.68999999999997
# new best with swap: 267.86000000000007
# new best with swap: 307.43
# new best with swap: 241.64000000000001
# new best with swap: 317.7199999999999
# new best with swap: 581.41
# new best with swap: 276.59999999999997
# new best with swap: 345.08000000000004
# new best with swap: 194.71
# new best with swap: 257.37
# new best with swap: 328.01
# new best with swap: 221.28000000000003
# new best with swap: 142.83
# new best with swap: 262.36000000000007
# new best with swap: 375.48
# new best with swap: 367.46
# new best with swap: 217.51
# new best with swap: 516.16
# new best with swap: 313.26
# new best with swap: 447.55
# new best with swap: 531.83
# new best with swap: 336.69000000000005
# new best with swap: 364.71
# new best with swap: 230.10000000000005
# new best with swap: 395.62
# new best with swap: 562.82
# new best with swap: 478.80999999999995
# new best with swap: 195.95000000000002
# new best with swap: 188.73999999999995
# new best with swap: 346.54999999999995
# new best with swap: 311.30999999999995
# new best with swap: 144.27999999999997
# new best with swap: 335.98999999999995
# new best with swap: 102.68000000000004
# new best with swap: 271.2100000000001
# new best with swap: 433.61
# new best with swap: 176.12999999999997
# new best with swap: 287.7299999999999
# new best with swap: 541.13
# new best with swap: 317.06000000000006
# new best with swap: 691.11
# new best with swap: 581.16
# new best with swap: 280.0799999999999
# new best with swap: 204.89
# new best with swap: 357.6700000000001
# new best with swap: 326.57
# new best with swap: 530.99
# new best with swap: 190.65
# new best with swap: 267.68
# new best with swap: 174.22999999999996
# new best with swap: 502.49
# new best with swap: 86.59
# new best with swap: 255.39
# new best with swap: 551.5899999999999
# new best with swap: 465.34
# new best with swap: 304.42999999999995
# new best with swap: 328.63
# new best with swap: 155.89000000000001
# new best with swap: 130.42000000000002
# new best with swap: 487.82
# new best with swap: 399.28000000000003
# new best with swap: 458.53000000000003
# new best with swap: 313.64
# new best with swap: 315.72
# new best with swap: 292.46
# new best with swap: 496.80999999999995
# new best with swap: 200.51
# new best with swap: 380.3
# new best with swap: 269.62
# new best with swap: 186.77000000000004
# new best with swap: 399.78
# new best with swap: 349.78999999999996
# new best with swap: 351.52000000000004
# new best with swap: 651.04
# new best with swap: 673.31
# new best with swap: 422.33000000000004
# new best with swap: 367.88999999999993
# new best with swap: 246.75
# new best with swap: 295.74
# new best with swap: 283.36
# new best with swap: 459.72
# new best with swap: 413.67999999999995
# new best with swap: 446.13
# new best with swap: 341.64
# new best with swap: 176.06
# new best with swap: 311.88
# new best with swap: 277.54999999999995
# new best with swap: 186.43000000000004
# new best with swap: 112.79
# new best with swap: 385.68000000000006
# new best with swap: 253.99999999999997
# new best with swap: 197.07000000000005
# new best with swap: 206.24
# new best with swap: 314.37
# new best with swap: 287.30000000000007
# new best with swap: 408.06
# new best with swap: 581.3399999999999
# new best with swap: 21.07000000000002
# new best with swap: 112.51
# new best with swap: 598.53
# new best with swap: 196.37000000000003
# new best with swap: 337.85
# new best with swap: 402.23
# new best with swap: 336.02000000000004
# new best with swap: 240.67000000000002
# new best with swap: 189.12999999999997
# new best with swap: 144.57999999999998
# new best with swap: 276.97
# new best with swap: 366.2
# new best with swap: 261.57
# new best with swap: 673.49
# new best with swap: 362.63000000000005
# new best with swap: 264.9700000000001
# new best with swap: 665.72
# new best with swap: 256.2
# new best with swap: 236.82999999999996
# new best with swap: 238.08000000000004
# new best with swap: 341.96
# new best with swap: 376.12
# new best with swap: 581.3399999999999
# new best with swap: 324.26
# new best with swap: 130.80000000000004
# new best with swap: 348.59
# new best with swap: 178.27
# new best with swap: 177.69000000000003
# new best with swap: 193.27999999999994
# new best with swap: 199.09
# new best with swap: 96.41000000000005
# new best with swap: 299.71000000000004
# new best with swap: 268.28
# new best with swap: 303.31
# new best with swap: 223.45
# new best with swap: 626.95
# new best with swap: 478.7
# new best with swap: 339.55
# new best with swap: 126.61
# new best with swap: 211.70000000000005
# new best with swap: 298.82000000000005
# new best with swap: 546.64
# new best with swap: 390.12
# new best with swap: 192.29999999999998
# new best with swap: 253.59
# new best with swap: 303.93000000000006
# new best with swap: 326.72
# new best with swap: 140.82000000000002
# new best with swap: 307.01000000000005
# new best with swap: 540.5899999999999
# new best with swap: 391.36
# new best with swap: 486.21999999999997
# new best with swap: 456.55
# new best with swap: 263.21
# new best with swap: 234.92
# new best with swap: 536.37
# new best with swap: 339.7900000000001
# new best with swap: 326.65000000000003
# new best with swap: 531.62
# new best with swap: 272.87
# new best with swap: 383.72
# new best with swap: 255.32000000000002
# new best with swap: 400.33000000000004
# new best with swap: 365.84000000000003
# new best with swap: 321.14000000000004
# new best with swap: 413.40000000000003
# new best with swap: 246.04000000000005
# new best with swap: 340.11
# new best with swap: 331.74
# new best with swap: 276.02
# new best with swap: 414.58
# new best with swap: 329.2300000000001
# new best with swap: 313.02
# new best with swap: 250.32
# new best with swap: 290.26
# new best with swap: 479.34
# new best with swap: 416.23
# new best with swap: 655.69
# new best with swap: 191.53999999999996
# new best with swap: 169.37000000000003
# new best with swap: 245.78
# new best with swap: 351.39
# new best with swap: 341.96
# new best with swap: 611.99
# new best with swap: 232.92
# new best with swap: 540.92
# new best with swap: 301.06
# new best with swap: 143.37999999999997
# new best with swap: 366.09000000000003
# new best with swap: 232.33
# new best with swap: 160.19999999999996
# new best with swap: 235.03000000000003
# new best with swap: 214.04
# new best with swap: 230.53
# new best with swap: 249.43000000000004
# new best with swap: 176.13999999999996
# new best with swap: 196.34000000000003
# new best with swap: 503.65
# new best with swap: 296.7
# new best with swap: 196.79999999999998
# new best with swap: 187.62000000000006
# new best with swap: 422.41999999999996
# new best with swap: 673.5
# new best with swap: 516.3
# new best with swap: 373.06
# new best with swap: 342.70000000000005
# new best with swap: 256.25
# new best with swap: 421.19
# new best with swap: 377.41999999999996
# new best with swap: 456.94
# new best with swap: 225.60000000000002
# new best with swap: 299.61
# new best with swap: 474.4599999999999
# new best with swap: 451.62
# new best with swap: 474.32
# new best with swap: 203.04000000000002
# new best with swap: 399.3
# new best with swap: 444.88
# new best with swap: 455.6
# new best with swap: 272.07
# new best with swap: 351.71000000000004
# new best with swap: 276.1
# new best with swap: 549.9200000000001
# new best with swap: 478.09000000000003
# new best with swap: 329.57
# new best with swap: 298.13
# new best with swap: 293.93
# new best with swap: 376.8
# new best with swap: 293.44
# new best with swap: 136.13
# new best with swap: 206.57000000000002
# new best with swap: 173.26000000000002
# new best with swap: 163.10999999999999
# new best with swap: 423.86
# new best with swap: 233.76000000000005
# new best with swap: 67.35000000000001
# new best with swap: 487.87
# new best with swap: 566.71
# new best with swap: 254.67999999999998
# new best with swap: 301.6099999999999
# new best with swap: 408.05
# new best with swap: 293.29999999999995
# new best with swap: 466.53
# new best with swap: 181.75000000000003
# new best with swap: 200.07000000000005
# new best with swap: 300.2500000000001
# new best with swap: 283.41999999999996
# new best with swap: 601.91
# new best with swap: 230.29000000000002
# new best with swap: 301.57000000000005
# new best with swap: 334.64
# new best with swap: 183.45999999999992
# new best with swap: 295.01
# new best with swap: 28.57
# new best with swap: 226.95000000000002
# new best with swap: 361.4700000000001
# new best with swap: 349.17
# new best with swap: 261.86
# new best with swap: 288.94000000000005
# new best with swap: 565.95
# new best with swap: 189.42000000000002
# new best with swap: 502.31
# new best with swap: 95.74000000000004
# new best with swap: 260.15
# new best with swap: 223.63
# new best with swap: 134.59
# new best with swap: 229.32
# new best with swap: 264.46
# new best with swap: 103.20000000000002
# new best with swap: 385.37
# new best with swap: 322.19000000000005
# new best with swap: 320.49
# new best with swap: 281.12
# new best with swap: 206.69
# new best with swap: 244.45999999999998
# new best with swap: 502.56
# new best with swap: 306.32000000000005
# new best with swap: 204.62
# new best with swap: 365.43000000000006
# new best with swap: 224.95
# new best with swap: 288.44000000000005
# new best with swap: 317.36
# new best with swap: 370.89
# new best with swap: 253.64000000000001
# new best with swap: 466.88
# new best with swap: 264.95
# new best with swap: 432.55
# new best with swap: 487.61
# new best with swap: 244.85000000000002
# new best with swap: 392.37
# new best with swap: 201.47000000000003
# new best with swap: 551.62
# new best with swap: 213.81999999999996
# new best with swap: 352.99
# new best with swap: 566.56
# new best with swap: 79.11
# new best with swap: 380.95000000000005
# new best with swap: 188.46000000000004
# new best with swap: 122.23000000000002
# new best with swap: 114.17
# new best with swap: 348.11
# new best with swap: 366.18999999999994
# new best with swap: 602.2
# new best with swap: 282.25
# new best with swap: 372.57000000000005
# new best with swap: 273.65
# new best with swap: 392.14
# new best with swap: 292.19
# new best with swap: 305.38000000000005
# new best with swap: 192.42
# new best with swap: 152.47999999999996
# new best with swap: 87.54
# new best with swap: 457.07
# new best with swap: 365.63
# new best with swap: 371.24
# new best with swap: 507.43
# new best with swap: 353.2900000000001
# new best with swap: 481.7
# new best with swap: 465.09999999999997
# new best with swap: 550.74
# new best with swap: 266.77
# new best with swap: 418.22
# new best with swap: 63.739999999999995
# new best with swap: 315.35
# new best with swap: 432.56
# new best with swap: 265.89
# new best with swap: 382.21
# new best with swap: 620.45
# new best with swap: 342.96000000000004
# new best with swap: 370.22999999999996
# new best with swap: 574.04
# new best with swap: 566.99
# new best with swap: 307.52
# new best with swap: 141.35000000000002
# new best with swap: 399.03
# new best with swap: 82.15
# new best with swap: 502.53000000000003
# new best with swap: 171.45
# new best with swap: 51.67
# new best with swap: 140.82000000000002
# new best with swap: 404.55
# new best with swap: 231.73000000000002
# new best with swap: 250.23
# new best with swap: 267.2599999999999
# new best with swap: 543.38
# new best with swap: 166.46000000000004
# new best with swap: 325.82000000000005
# new best with swap: 178.77
# new best with swap: 627.08
# new best with swap: 187.57
# new best with swap: 367.18000000000006
# new best with swap: 596.42
# new best with swap: 307.47999999999996
# new best with swap: 299.72
# new best with swap: 253.28000000000003
# new best with swap: 292.34000000000003
# new best with swap: 171.64
# new best with swap: 372.74
# new best with swap: 284.0300000000001
# new best with swap: 269.76
# new best with swap: 258.08000000000004
# new best with swap: 260.57
# new best with swap: 353.19999999999993
# new best with swap: 615.07
# new best with swap: 416.68
# new best with swap: 602.79
# new best with swap: 185.10999999999996
# new best with swap: 314.26
# new best with swap: 561.51
# new best with swap: 566.6
# new best with swap: 230.54
# new best with swap: 264.2
# new best with swap: 538.54
# new best with swap: 602.01
# new best with swap: 290.66
# new best with swap: 291.35
# new best with swap: 432.66
# new best with swap: 472.12
# new best with swap: 337.84000000000003
# new best with swap: 229.85000000000002
# new best with swap: 210.49
# new best with swap: 252.89000000000004
# new best with swap: 285.38
# new best with swap: 304.0999999999999
# new best with swap: 243.70000000000002
# new best with swap: 306.13000000000005
# new best with swap: 271.07
# new best with swap: 262.58
# new best with swap: 222.94999999999996
# new best with swap: 275.46000000000004
# new best with swap: 186.22999999999993
# new best with swap: 347.69
# new best with swap: 132.03
# new best with swap: 192.29999999999998
# new best with swap: 396.93999999999994
# new best with swap: 353.07
# new best with swap: 535.0
# new best with swap: 142.41999999999996
# new best with swap: 469.15999999999997
# new best with swap: 511.08000000000004
# new best with swap: 107.08000000000001
# new best with swap: 388.44000000000005
# new best with swap: 527.25
# new best with swap: 187.44999999999996
# new best with swap: 320.61
# new best with swap: 157.71000000000004
# new best with swap: 291.38
# new best with swap: 185.54000000000002
# new best with swap: 363.36000000000007
# new best with swap: 611.99
# new best with swap: 609.37
# new best with swap: 201.28000000000003
# new best with swap: 87.72
# new best with swap: 101.41
# new best with swap: 43.4
# new best with swap: 218.19999999999993
# new best with swap: 564.8
# new best with swap: 245.59000000000003
# new best with swap: 381.83
# new best with swap: 295.51000000000005
# new best with swap: 204.50000000000006
# new best with swap: 295.03
# new best with swap: 370.17999999999995
# new best with swap: 263.87
# new best with swap: 263.01
# new best with swap: 282.22
# new best with swap: 138.02999999999997
# new best with swap: 296.86
# new best with swap: 430.61999999999995
# new best with swap: 317.65
# new best with swap: 362.91
# new best with swap: 64.75
# new best with swap: 602.09
# new best with swap: 239.3
# new best with swap: 241.57000000000002
# new best with swap: 320.37000000000006
# new best with swap: 356.52
# new best with swap: 478.99
# new best with swap: 207.35000000000005
# new best with swap: 313.77
# new best with swap: 282.35
# new best with swap: 270.05
# new best with swap: 135.26
# new best with swap: 410.4200000000001
# new best with swap: 250.71000000000004
# new best with swap: 231.93000000000004
# new best with swap: 636.19
# new best with swap: 339.09999999999997
# new best with swap: 197.61999999999998
# new best with swap: 642.3
# new best with swap: 417.99
# new best with swap: 367.73
# new best with swap: 502.82
# new best with swap: 402.96000000000004
# new best with swap: 320.38
# new best with swap: 325.57
# new best with swap: 133.90000000000003
# new best with swap: 150.48000000000002
# new best with swap: 284.34
# new best with swap: 374.13999999999993
# new best with swap: 165.20000000000005
# new best with swap: 263.05000000000007
# new best with swap: 502.7
# new best with swap: 303.28000000000003
# new best with swap: 635.85
# new best with swap: 264.85999999999996
# new best with swap: 277.6
# new best with swap: 280.13
# new best with swap: 460.1
# new best with swap: 270.29999999999995
# new best with swap: 167.53
# new best with swap: 60.66000000000001
# new best with swap: 262.32000000000005
# new best with swap: 364.62
# new best with swap: 427.87
# new best with swap: 288.51
# new best with swap: 488.16
# new best with swap: 357.26
# new best with swap: 629.98
# new best with swap: 477.6
# new best with swap: 381.95
# new best with swap: 487.21
# new best with swap: 266.32000000000005
# new best with swap: 291.12
# new best with swap: 110.75000000000001
# new best with swap: 72.93
# new best with swap: 100.32000000000001
# new best with swap: 536.6
# new best with swap: 157.12
# new best with swap: 425.70000000000005
# new best with swap: 244.48
# new best with swap: 267.72
# new best with swap: 377.29999999999995
# new best with swap: 278.07000000000005
# new best with swap: 509.89
# new best with swap: 252.5
# new best with swap: 363.95
# new best with swap: 399.12
# new best with swap: 264.8400000000001
# new best with swap: 680.93
# new best with swap: 157.69
# new best with swap: 364.78
# new best with swap: 234.54
# new best with swap: 334.58
# new best with swap: 506.21000000000004
# new best with swap: 405.95
# new best with swap: 471.15
# new best with swap: 560.59
# new best with swap: 316.52000000000004
# new best with swap: 158.69
# new best with swap: 563.65
# new best with swap: 182.48000000000005
# new best with swap: 431.9
# new best with swap: 305.38
# new best with swap: 387.79
# new best with swap: 697.87
# new best with swap: 387.47
# new best with swap: 355.41999999999996
# new best with swap: 559.2
# new best with swap: 233.54000000000002
# new best with swap: 295.19
# new best with swap: 403.66
# new best with swap: 291.00000000000006
# new best with swap: 367.04999999999995
# new best with swap: 341.47
# new best with swap: 352.29
# new best with swap: 260.03
# new best with swap: 311.89
# new best with swap: 385.92
# new best with swap: 341.68
# new best with swap: 304.00000000000006
# new best with swap: 439.18
# new best with swap: 264.05999999999995
# new best with swap: 388.01
# new best with swap: 312.20000000000005
# new best with swap: 366.82
# new best with swap: 386.01
# new best with swap: 355.62
# new best with swap: 275.08
# new best with swap: 251.62
# new best with swap: 197.80999999999997
# new best with swap: 185.97000000000003
# new best with swap: 275.15999999999997
# new best with swap: 395.45000000000005
# new best with swap: 211.73000000000005
# new best with swap: 295.11
# new best with swap: 356.51
# new best with swap: 673.61
# new best with swap: 357.81
# new best with swap: 361.47
# new best with swap: 189.46000000000004
# new best with swap: 216.45000000000005
# new best with swap: 110.44
# new best with swap: 363.64
# new best with swap: 267.63
# new best with swap: 308.55
# new best with swap: 393.14
# new best with swap: 586.53
# new best with swap: 447.08000000000004
# new best with swap: 89.33000000000001
# new best with swap: 181.01999999999992
# new best with swap: 445.97
# new best with swap: 334.77
# new best with swap: 307.69
# new best with swap: 270.91999999999996
# new best with swap: 451.96000000000004
# new best with swap: 346.90999999999997
# new best with swap: 208.82
# new best with swap: 113.98000000000002
# new best with swap: 102.26
# new best with swap: 286.90999999999997
# new best with swap: 314.03
# new best with swap: 455.05
# new best with swap: 109.65
# new best with swap: 642.3
# new best with swap: 310.65999999999997
# new best with swap: 502.31
# new best with swap: 339.01
# new best with swap: 309.42
# new best with swap: 441.25
# new best with swap: 279.38
# new best with swap: 642.17
# new best with swap: 326.04999999999995
# new best with swap: 485.6
# new best with swap: 321.45000000000005
# new best with swap: 203.13000000000002
# new best with swap: 425.41999999999996
# new best with swap: 297.01
# new best with swap: 220.83
# new best with swap: 596.37
# new best with swap: 303.89000000000004
# new best with swap: 248.44
# new best with swap: 366.46999999999997
# new best with swap: 236.51000000000002
# new best with swap: 296.93
# new best with swap: 349.12
# new best with swap: 324.85
# new best with swap: 111.32999999999998
# new best with swap: 392.49
# new best with swap: 115.75000000000001
# new best with swap: 183.45999999999992
# new best with swap: 222.65
# new best with swap: 261.56
# new best with swap: 293.53000000000003
# new best with swap: 177.54999999999995
# new best with swap: 446.26
# new best with swap: 340.65
# new best with swap: 123.86
# new best with swap: 363.12
# new best with swap: 250.35
# new best with swap: 602.29
# new best with swap: 424.35
# new best with swap: 522.29
# new best with swap: 421.06
# new best with swap: 139.76000000000005
# new best with swap: 238.93000000000004
# new best with swap: 370.69
# new best with swap: 343.29
# new best with swap: 275.97
# new best with swap: 443.79
# new best with swap: 366.84000000000003
# new best with swap: 265.75000000000006
# new best with swap: 580.52
# new best with swap: 297.49
# new best with swap: 343.82000000000005
# new best with swap: 426.93
# new best with swap: 223.55000000000004
# new best with swap: 290.9599999999999
# new best with swap: 320.14000000000004
# new best with swap: 322.28999999999996
# new best with swap: 439.04
# new best with swap: 329.22
# new best with swap: 287.91
# new best with swap: 132.02
# new best with swap: 540.42
# new best with swap: 225.16999999999996
# new best with swap: 293.65000000000003
# new best with swap: 307.11
# new best with swap: 322.2100000000001
# new best with swap: 88.97000000000001
# new best with swap: 204.18000000000006
# new best with swap: 440.86
# new best with swap: 32.40999999999999
# new best with swap: 528.23
# new best with swap: 378.72
# new best with swap: 440.65
# new best with swap: 234.51999999999998
# new best with swap: 368.0600000000001
# new best with swap: 363.68000000000006
# new best with swap: 267.46000000000004
# new best with swap: 195.15999999999997
# new best with swap: 119.34000000000002
# new best with swap: 326.52
# new best with swap: 255.39000000000001
# new best with swap: 158.05
# new best with swap: 309.05999999999995
# new best with swap: 242.81999999999996
# new best with swap: 118.34
# new best with swap: 502.38
# new best with swap: 236.98
# new best with swap: 401.52
# new best with swap: 222.11000000000007
# new best with swap: 128.48999999999998
# new best with swap: 352.95000000000005
# new best with swap: 124.10000000000001
# new best with swap: 66.74000000000001
# new best with swap: 253.09999999999997
# new best with swap: 161.31000000000003
# new best with swap: 365.51
# new best with swap: 269.9200000000001
# new best with swap: 219.55
# new best with swap: 221.55000000000004
# new best with swap: 389.07000000000005
# new best with swap: 197.29000000000002
# new best with swap: 265.72
# new best with swap: 420.11
# new best with swap: 184.06999999999994
# new best with swap: 471.38
# new best with swap: 242.34
# new best with swap: 400.14
# new best with swap: 500.02
# new best with swap: 318.25
# new best with swap: 456.85
# new best with swap: 207.07
# new best with swap: 218.29000000000002
# new best with swap: 304.41999999999996
# new best with swap: 85.75999999999999
# new best with swap: 76.87000000000002
# new best with swap: 385.52
# new best with swap: 691.36
# new best with swap: 447.38
# new best with swap: 397.87000000000006
# new best with swap: 335.79
# new best with swap: 451.89
# new best with swap: 248.55
# new best with swap: 256.7200000000001
# new best with swap: 595.42
# new best with swap: 369.98999999999995
# new best with swap: 380.18
# new best with swap: 360.01
# new best with swap: 357.71999999999997
# new best with swap: 334.5899999999999
# new best with swap: 160.82
# new best with swap: 322.14
# new best with swap: 665.72
# new best with swap: 305.40000000000003
# new best with swap: 364.14
# new best with swap: 250.33999999999997
# new best with swap: 297.79
# new best with swap: 151.82
# new best with swap: 212.86
# new best with swap: 464.06000000000006
# new best with swap: 279.13
# new best with swap: 324.52
# new best with swap: 316.65
# new best with swap: 359.86
# new best with swap: 175.2
# new best with swap: 207.82000000000002
# new best with swap: 193.84000000000003
# new best with swap: 174.75
# new best with swap: 566.25
# new best with swap: 249.54000000000002
# new best with swap: 275.57000000000005
# new best with swap: 306.55
# new best with swap: 486.88
# new best with swap: 362.58000000000004
# new best with swap: 575.35
# new best with swap: 320.15
# new best with swap: 451.86
# new best with swap: 441.98
# new best with swap: 105.9
# new best with swap: 470.26
# new best with swap: 242.25
# new best with swap: 198.65999999999997
# new best with swap: 186.96000000000004
# new best with swap: 355.83000000000004
# new best with swap: 405.89000000000004
# new best with swap: 198.54
# new best with swap: 445.15000000000003
# new best with swap: 205.25
# new best with swap: 505.39000000000004
# new best with swap: 201.43999999999997
# new best with swap: 358.87000000000006
# new best with swap: 90.25000000000003
# new best with swap: 511.19
# new best with swap: 620.45
# new best with swap: 219.87
# new best with swap: 226.60000000000002
# new best with swap: 330.06
# new best with swap: 63.69
# new best with swap: 337.11
# new best with swap: 475.81
# new best with swap: 289.46000000000004
# new best with swap: 326.65000000000003
# new best with swap: 176.12999999999997
# new best with swap: 565.95
# new best with swap: 248.55
# new best with swap: 498.43999999999994
# new best with swap: 556.8
# new best with swap: 132.45999999999998
# new best with swap: 282.12
# new best with swap: 284.02
# new best with swap: 160.35
# new best with swap: 427.76
# new best with swap: 179.97000000000003
# new best with swap: 200.39999999999998
# new best with swap: 221.44
# new best with swap: 482.4
# new best with swap: 496.85
# new best with swap: 328.19
# new best with swap: 381.95
# new best with swap: 381.02000000000004
# new best with swap: 429.36
# new best with swap: 278.13
# new best with swap: 486.83
# new best with swap: 440.89
# new best with swap: 261.97
# new best with swap: 602.4300000000001
# new best with swap: 548.35
# new best with swap: 385.74
# new best with swap: 346.6700000000001
# new best with swap: 518.5699999999999
# new best with swap: 257.53
# new best with swap: 292.31
# new best with swap: 199.55000000000004
# new best with swap: 267.61999999999995
# new best with swap: 74.55
# new best with swap: 245.20999999999998
# new best with swap: 145.48999999999998
# new best with swap: 470.15
# new best with swap: 227.24
# new best with swap: 236.38
# new best with swap: 72.97000000000001
# new best with swap: 331.02
# new best with swap: 368.12999999999994
# new best with swap: 167.01000000000005
# new best with swap: 292.3
# new best with swap: 387.47
# new best with swap: 196.96
# new best with swap: 110.74000000000001
# new best with swap: 269.59000000000003
# new best with swap: 300.02
# new best with swap: 405.4
# new best with swap: 199.48

# %%
best
# Out:
# np.float64(199.48)

# %%
import random
import numpy as np

class VRPTW:
    def __init__(self, num_vehicles, vehicle_capacity, customers, distance_matrix):
        self.num_vehicles = num_vehicles
        self.vehicle_capacity = vehicle_capacity
        self.customers = customers
        self.distance_matrix = distance_matrix
        self.best_solution = None
        self.best_cost = float('inf')

    def initialize_solution(self):
        solution = [[] for _ in range(self.num_vehicles)]
        customers = list(self.customers.keys())[1:]  # exclude the depot (index 0)
        random.shuffle(customers)
        
        for customer in customers:
            vehicle = random.choice(solution)
            vehicle.append(customer)
        
        return solution

    def evaluate_solution(self, solution):
        total_cost = 0
        for route in solution:
            route_cost = 0
            load = 0
            time = 0
            prev_customer = 0  # start from depot
            for customer in route:
                load += self.customers[customer]['demand']
                if load > self.vehicle_capacity:
                    return float('inf')
                
                time += self.distance_matrix[prev_customer][customer]
                if time > self.customers[customer]['time_window'][1]:
                    return float('inf')
                
                time = max(time, self.customers[customer]['time_window'][0])
                route_cost += self.distance_matrix[prev_customer][customer]
                prev_customer = customer
            
            route_cost += self.distance_matrix[prev_customer][0]  # return to depot
            total_cost += route_cost
        
        return total_cost

    def get_neighbors(self, solution):
        neighbors = []
        for i in range(len(solution)):
            for j in range(len(solution)):
                if i != j:
                    for k in range(len(solution[i])):
                        for l in range(len(solution[j])):
                            neighbor = [list(route) for route in solution]
                            neighbor[i][k], neighbor[j][l] = neighbor[j][l], neighbor[i][k]
                            neighbors.append(neighbor)
        return neighbors

    def tabu_search(self, iterations, tabu_tenure):
        current_solution = self.initialize_solution()
        current_cost = self.evaluate_solution(current_solution)
        
        tabu_list = []
        self.best_solution = current_solution
        self.best_cost = current_cost
        
        for _ in range(iterations):
            neighbors = self.get_neighbors(current_solution)
            neighbors = [(neighbor, self.evaluate_solution(neighbor)) for neighbor in neighbors]
            neighbors = sorted(neighbors, key=lambda x: x[1])
            
            for neighbor, cost in neighbors:
                if neighbor not in tabu_list or cost < self.best_cost:
                    current_solution = neighbor
                    current_cost = cost
                    tabu_list.append(neighbor)
                    if len(tabu_list) > tabu_tenure:
                        tabu_list.pop(0)
                    
                    if current_cost < self.best_cost:
                        self.best_solution = current_solution
                        self.best_cost = current_cost
                    break
        
        return self.best_solution, self.best_cost

# Example usage:

# Define the problem parameters
num_vehicles = 3
vehicle_capacity = 100
customers = {
    0: {'demand': 0, 'time_window': (0, 100)},  # depot
    1: {'demand': 10, 'time_window': (10, 20)},
    2: {'demand': 20, 'time_window': (15, 25)},
    3: {'demand': 30, 'time_window': (20, 30)},
    4: {'demand': 40, 'time_window': (25, 35)},
}
distance_matrix = np.array([
    [0, 10, 20, 30, 40],
    [10, 0, 15, 25, 35],
    [20, 15, 0, 10, 20],
    [30, 25, 10, 0, 10],
    [40, 35, 20, 10, 0],
])

# Create VRPTW instance
vrptw = VRPTW(num_vehicles, vehicle_capacity, customers, distance_matrix)

# Perform Tabu Search
best_solution, best_cost = vrptw.tabu_search(iterations=100, tabu_tenure=10)

print("Best Solution:", best_solution)
print("Best Cost:", best_cost)
